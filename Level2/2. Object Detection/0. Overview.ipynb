# %% [markdown]
# ## Object Detection
# - classification과 달리 하나의 이미지 안에 여러 정답을 발견해야 한다.
# - Segmentation을 통해 객체들 간에 영역을 구분하는 task도 포함한다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## History

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Evaluation
# ### 1. 성능
# - mAP : 각 클래스당 AP의 평균 (Average Precision)
# - precision은 모델이 Positive라고 예측한 모든 케이스들 중에서 실제로 정답인 것
# ![image.png](attachment:image.png)

# %% [markdown]
# ### AP
# - PR Curve의 아래 면적을 구하면 AP다.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### mAP
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. 속도
# - FPS
# - FLOPS

# %% [markdown]
# ## Library
# - MMDetection
# - Detectron2
# - YOLO v5
# - EfficientDet

# %% [markdown]
# - 통합된 라이브러리가 부재 중이다.
# - 높은 성능을 내기 위해서 무거운 모델을 활용하게 된다.
