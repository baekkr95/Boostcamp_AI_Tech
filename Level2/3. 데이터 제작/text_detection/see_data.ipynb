# %%
# %matplotlib inline
import glob
import json
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pathlib import Path
from PIL import Image, ImageDraw, ImageFont
from collections import Counter
import numpy as np
import cv2

# %%
def read_json(filename):
    with Path(filename).open(encoding='utf8') as handle:
        ann = json.load(handle)
    return ann

# %%
# gt file과 raw image file path를 이용해 데이터를 불러온다. 아래 경로는 예시.
data = read_json("../input/data/ICDAR17_Korean/ufo/train.json")

# %%
scale = 5 # 이미지 scale 조절, 나누는 값 1 or 5
def scaling(p): # scale에 맞춰 좌표값 조절, list(map(scaling, points))
    return [p[0]/scale, p[1]/scale]

# %%
fontsize = 20 * (5//scale)
fnt = ImageFont.truetype("NanumSquareR.ttf", fontsize, encoding="UTF-8")

# %%
cnt = 0
for img_name in sorted(data['images']):
    print(img_name)
    img = Image.open("../input/data/ICDAR17_Korean/images/" + img_name)
    w, h = data['images'][img_name]['img_w']//scale, data['images'][img_name]['img_h']//scale
    # w, h = img.width//scale, img.height//scale
    resize_img = img.resize((w, h))
    draw = ImageDraw.Draw(resize_img)

    # 단어 표시
    words = data['images'][img_name]['words']
    for word in words:
        # print(words[word]['points'])
        # print(words[word]['points'])
        points = list(map(scaling, words[word]['points']))
        # print(points+[points[0]])
        # print(points)
        draw.line(points+[points[0]], fill="red", width=2*(5//scale))
        text = words[word]['transcription']
        tw, th = fnt.getsize(text)
        draw.text((points[0][0], points[0][1]-th), text, font=fnt, fill="red")

    resize_img.show()
    if cnt == 1:
        break
    cnt += 1
# Out:
# img_1001.jpg
# [[80.0, 807.0], [607.0, 812.0], [592.0, 1037.0], [126.0, 1037.0]]
# [[678.0, 793.0], [1160.0, 803.0], [1155.0, 1037.0], [691.0, 1037.0]]
# [[1252.0, 793.0], [1767.0, 783.0], [1752.0, 1027.0], [1267.0, 1022.0]]
# [[109.0, 1089.0], [573.0, 1080.0], [557.0, 1299.0], [124.0, 1295.0]]
# [[708.0, 1089.0], [1168.0, 1094.0], [1199.0, 1280.0], [718.0, 1314.0]]
# [[1296.0, 1089.0], [1739.0, 1094.0], [1767.0, 1299.0], [1221.0, 1323.0]]
# <PIL.Image.Image image mode=RGB size=367x489 at 0x7F5881E19D90>
# img_1002.jpg
# [[578.0, 595.0], [1646.0, 666.0], [1837.0, 1010.0], [300.0, 985.0]]
# [[297.0, 562.0], [758.0, 455.0], [852.0, 608.0], [310.0, 718.0]]
# <PIL.Image.Image image mode=RGB size=489x367 at 0x7F58EC764B50>

# %% [markdown]
# ### Annotation 하나씩 확인하기

# %%
for i, img_name in enumerate(sorted(data['images'])):
    if i == 1:
        print(img_name)
        img = Image.open("../input/data/ICDAR17_Korean/images/" + img_name)
        w, h = data['images'][img_name]['img_w']//scale, data['images'][img_name]['img_h']//scale
        # w, h = img.width//scale, img.height//scale
        resize_img = img.resize((w, h))

        img_np = np.array(resize_img)  
        img_cv = cv2.cvtColor(img_np, cv2.COLOR_RGB2BGR)

        draw = ImageDraw.Draw(resize_img)
        # 단어 표시
        words = data['images'][img_name]['words']
        for word in words:
            points = list(map(scaling, words[word]['points']))
            min_x, max_x, min_y, max_y = w, 0, h, 0
            # find left_top, right_bottom
            for p in points:
                min_x = min(min_x, p[0])
                max_x = max(max_x, p[0])
                min_y = min(min_y, p[1])
                max_y = max(max_y, p[1])
            draw.line(points+[points[0]], fill="red", width=2*(5//scale))
            text = words[word]['transcription']
            tw, th = fnt.getsize(text)
            draw.text((points[0][0], points[0][1]-th), text, font=fnt, fill="red")

            mask = np.ones(img_cv.shape, dtype=np.uint8)
            mask.fill(255)
            # points to be cropped
            roi_corners = np.array([points], dtype=np.int32)
            # fill the ROI into the mask
            cv2.fillPoly(mask, roi_corners, 0)
            # applying th mask to original image
            masked_image = cv2.bitwise_or(img_cv, mask)
            # The resultant image
            color_coverted = cv2.cvtColor(masked_image, cv2.COLOR_BGR2RGB)
            masked_img = Image.fromarray(color_coverted)
            cropped_img = masked_img.crop((min_x, min_y, max_x, max_y))
            
            cropped_img=cropped_img.resize((200,200))
            cropped_img.show()
            print(text)
            # cv2.imshow('new_masked_image', masked_image)
        
        resize_img.show()
# Out:
# img_1002.jpg
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FF40446AEB0>
# 요술램프
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FF40446AEB0>
# 유로텍스
# <PIL.Image.Image image mode=RGB size=489x367 at 0x7FF39951A5E0>

# %%
for i, img_name in enumerate(sorted(data['images'])):
    if i == 1:
        print(img_name)
        img = Image.open("../input/data/ICDAR17_Korean/images/" + img_name)
        w, h = data['images'][img_name]['img_w']//scale, data['images'][img_name]['img_h']//scale
        # w, h = img.width//scale, img.height//scale
        resize_img = img.resize((w, h))

        img_np = np.array(resize_img)  
        img_cv = cv2.cvtColor(img_np, cv2.COLOR_RGB2BGR)

        cv2.imshow(img_cv)
# Out:
# img_1002.jpg
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_14140/396506945.py in <module>
#      10         img_cv = cv2.cvtColor(img_np, cv2.COLOR_RGB2BGR)
#      11
# ---> 12         cv2.imshow(img_cv)
#
# error: OpenCV(4.5.4-dev) :-1: error: (-5:Bad argument) in function 'imshow'
# > Overload resolution failed:
# >  - imshow() missing required argument 'mat' (pos 2)
# >  - imshow() missing required argument 'mat' (pos 2)
# >  - imshow() missing required argument 'mat' (pos 2)

# %%
import cv2
import numpy as np

image = cv2.imread('/opt/ml/input/data/ICDAR17_Korean/images/img_992.jpg')

cv2.imshow("img", image)
# Out:
# Error: Canceled future for execute_request message before replies were done
# at t.KernelShellFutureHandler.dispose (/opt/ml/.vscode-server/extensions/ms-toolsai.jupyter-2022.3.1000901801/out/extension.js:2:1204175)
# at /opt/ml/.vscode-server/extensions/ms-toolsai.jupyter-2022.3.1000901801/out/extension.js:2:1223227
# at Map.forEach (<anonymous>)
# at v._clearKernelState (/opt/ml/.vscode-server/extensions/ms-toolsai.jupyter-2022.3.1000901801/out/extension.js:2:1223212)
# at v.dispose (/opt/ml/.vscode-server/extensions/ms-toolsai.jupyter-2022.3.1000901801/out/extension.js:2:1216694)
# at /opt/ml/.vscode-server/extensions/ms-toolsai.jupyter-2022.3.1000901801/out/extension.js:2:533674
# at t.swallowExceptions (/opt/ml/.vscode-server/extensions/ms-toolsai.jupyter-2022.3.1000901801/out/extension.js:2:913059)
# at dispose (/opt/ml/.vscode-server/extensions/ms-toolsai.jupyter-2022.3.1000901801/out/extension.js:2:533652)
# at t.RawSession.dispose (/opt/ml/.vscode-server/extensions/ms-toolsai.jupyter-2022.3.1000901801/out/extension.js:2:537330)
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (node:internal/process/task_queues:96:5)
