# %% [markdown]
# <a href="https://colab.research.google.com/github/baekkr95/Boostcamp_AI_Tech/blob/main/%EC%B6%94%EA%B0%80%ED%95%99%EC%8A%B5/%EC%BD%94%EB%9E%A9%20%EC%97%B0%EB%8F%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $Y = X*B + \epsilon$
